# %%
from tkinter import *
from tkinter import ttk
import mysql.connector
import tkinter as tk
import os
con=mysql.connector.connect(
host="localhost",
user="root",
passwd="9640499993",
database="PMS"
)
cursor=con.cursor()
#cursor.execute("create database PMS")
#cursor.execute("create table admin ( id int auto_increment primary key ,username varchar(255), password varchar(255))")
#cursor.execute("create table users(Name varchar(255), Vehicle_number varchar(255),wheeler int(5),Phone_Number varchar(255))")
#cursor.execute("create table users1(Name varchar(255), Vehicle_number varchar(255),wheeler int(5),Phone_Number varchar(255))") 
root=Tk()
root.geometry("900x700")
root.configure(bg='grey')

user=StringVar()
pswd=StringVar()

w = Frame ( root,bg="white")
w.place(x = 0, y = 675, width = 900,height=10) 
x= Frame ( root,bg="red")
x.place(x = 0, y = 690, width = 900,height=10) 
y = Frame ( root,bg="red")
y.place(x = 0, y = 0, width = 900,height=10)
z = Frame ( root,bg="white")
z.place(x = 0, y = 15, width = 900,height=10) 
############################################################################################

def num():
    root=Tk()
    root.geometry("750x700")
    root.configure(bg='Teal')
    w = Frame( root,bg="white")
    w.place(x = 0, y = 675, width = 900,height=10) 
    x= Frame ( root,bg="red")
    x.place(x = 0, y = 690, width = 900,height=10) 
    y = Frame ( root,bg="red")
    y.place(x = 0, y = 0, width = 900,height=10)
    z = Frame ( root,bg="white")
    z.place(x = 0, y = 15, width = 900,height=10) 
    wrapper=LabelFrame(root,text="ENTER THE DETAILS",borderwidth=10,foreground="green",font=50)
    wrapper.pack(fill="both", expand="yes", padx=100, pady=10) 
    def home():
        root.destroy()
        login()
    def enter():
        wheeler=r1.get()
        vechile_no=ent1.get()
        Name=ent2.get()
        phone_number=ent3.get()
        print("name" ,Name)
        print("vechile" ,vechile_no)
        print("wheeler",wheeler)
        print("phone",phone_number)
        sql="insert into users(Name,Vehicle_number,wheeler,Phone_Number) values (%s,%s,%s,%s)" 
        sql2="insert into users1(Name,Vehicle_number,wheeler,Phone_Number) values (%s,%s,%s,%s)" 
        val=[(Name,vechile_no,wheeler,phone_number)]
        cursor.executemany(sql,val)
        cursor.executemany(sql2,val)
        cursor.execute("select * from users") 
        if(wheeler==2):
            lb4=Label(wrapper,text="Bill is 20",width=20,font=("bold",15))
            lb4.place(x=60,y=480)
        else:
            lb4=Label(wrapper,text="Bill is 40",width=20,font=("bold",15))
            lb4.place(x=60,y=480)
        #mesasagebox.showinfo("information",message="SUCCESFULLY INSERTED ")        
        result=cursor.fetchall() 
        print(result) 
        for i in result: 
            print(i)

    
    

############

    vechile=StringVar()
    name=StringVar() 
    phone=StringVar()
    lb1=Label(wrapper, text="VECHILE NUMBER",width=20,font=("bold",15)) 
    lb1.place(x=60,y=200)
    ent1=Entry(wrapper,textvariable=vechile)
    ent1.place(x=280,y=205)
    lb2=Label(wrapper,text="NAME",width=20,font=("bold",15))
    lb2.place(x=60,y=145)
    ent2=Entry(wrapper,textvariable=name)
    ent2.place(x=280,y=148)
    lb3=Label(wrapper,text="PHONE NUMBER",width=20,font=("bold",15))
    lb3.place(x=60,y=255)
    ent3=Entry(wrapper,textvariable=phone)
    ent3.place(x=280,y=259)
#####################################
    var=IntVar()
    lb4=Label(wrapper,text="VECHILE TYPE",width=20,font=("bold",15))
    lb4.place(x=60,y=360)
    r1=Entry(wrapper,width=10,font=("bold",15),textvariable=var)
    r1.place(x=280,y=359)
#######################################
#######################################
    btn=Button(wrapper,text="ENTER",width=20,bg='black',fg='white',command=enter,borderwidth=6) 
    btn.place(x=150,y=430)
    btn2=Button(wrapper,text="HOME",width=20,bg='black',fg='white',command=home,borderwidth=6) 
    btn2.place(x=150,y=530)

    mainloop()
    

    

######################################################################################################
def showw2():
    root=Tk()
    root.geometry("900x700")
    root.configure(bg='Teal')
    w = Frame ( root,bg="white")
    w.place(x = 0, y = 675, width = 900,height=10) 
    x= Frame ( root,bg="red")
    x.place(x = 0, y = 690, width = 900,height=10) 
    y = Frame ( root,bg="red")
    y.place(x = 0, y = 0, width = 900,height=10)
    z = Frame ( root,bg="white")
    z.place(x = 0, y = 15, width = 900,height=10) 
    ################################################
    def update(rows):
        trv.delete(*trv.get_children())
        for i in rows:
            trv.insert('',0,value=i)
        
    def search():
        e2=q.get()
        query=("select Name,Vehicle_number,wheeler  from users1 where fisrt_name LIKE '%"+e2+"%' ")
        cursor.execute(query)
        rows=cursor.fetchall()
        update(rows)
    
    def clear():
        query=("select Name,Vehicle_number,wheeler from users1 ")
        cursor.execute(query)
        rows=cursor.fetchall()
        update(rows)
    
    
    wrapper1=LabelFrame(root, text="MATCH")
    wrapper2=LabelFrame(root,text="DETAIL")
    #================================================================
    # tree view
    trv=ttk.Treeview(wrapper1, column=(1,2,3), show="headings",height="13")
    trv.pack()
    trv.heading(1,text="USER Name")
    trv.heading(2,text="Vehicle no")
    trv.heading(3,tex="wheelers")

#====================================================
    cursor.execute("select Name, Vehicle_number,wheeler from users1")
    rows=cursor.fetchall()
    update(rows)

    q=StringVar()


    lb1=Label(wrapper2, text="SEARCH")
    lb1.pack(side=LEFT,padx=10)
    ent=Entry(wrapper2,textvariable=q)
    ent.pack(side=LEFT,pady=10)
    btn=Button(wrapper2,text="SEARCH",command=search)
    btn.pack(side=LEFT,padx=10)

    clbtn=Button(wrapper2,text="CLEAR",command=clear)
    clbtn.pack(side=LEFT,padx=10)

#===============================================================
    wrapper1.pack(fill="both", expand="yes", padx=20, pady=20)
    wrapper2.pack(fill="both", expand="yes", padx=20, pady=20)
#================================================================
    def home():
        root.destroy()
        login()

    btn2=Button(wrapper2,text="HOME",width=20,bg='black',fg='white',command=home,borderwidth=6) 
    btn2.pack()

    root.mainloop()
    
    
def showw():
    
    root=Tk()
    root.geometry("900x700")
    root.configure(bg='Teal')
    w = Frame ( root,bg="white")
    w.place(x = 0, y = 675, width = 900,height=10) 
    x= Frame ( root,bg="red")
    x.place(x = 0, y = 690, width = 900,height=10) 
    y = Frame ( root,bg="red")
    y.place(x = 0, y = 0, width = 900,height=10)
    z = Frame ( root,bg="white")
    z.place(x = 0, y = 15, width = 900,height=10) 
    ################################################
    def update(rows):
        trv.delete(*trv.get_children())
        for i in rows:
            trv.insert('',0,value=i)
        
    def search():
        e2=q.get()
        query=("select Name,Vehicle_number,wheeler  from users where fisrt_name LIKE '%"+e2+"%' ")
        cursor.execute(query)
        rows=cursor.fetchall()
        update(rows)
    
    def clear():
        query=("select Name,Vehicle_number,wheeler from users ")
        cursor.execute(query)
        rows=cursor.fetchall()
        update(rows)
    
    
    wrapper1=LabelFrame(root, text="MATCH")
    wrapper2=LabelFrame(root,text="DETAIL")
    #================================================================
    # tree view
    trv=ttk.Treeview(wrapper1, column=(1,2,3), show="headings",height="13")
    trv.pack()
    trv.heading(1,text="USER Name")
    trv.heading(2,text="Vehicle no")
    trv.heading(3,tex="wheelers")

#====================================================
    cursor.execute("select Name, Vehicle_number,wheeler from users")
    rows=cursor.fetchall()
    update(rows)

    q=StringVar()


    lb1=Label(wrapper2, text="SEARCH")
    lb1.pack(side=LEFT,padx=10)
    ent=Entry(wrapper2,textvariable=q)
    ent.pack(side=LEFT,pady=10)
    btn=Button(wrapper2,text="SEARCH",command=search)
    btn.pack(side=LEFT,padx=10)

    clbtn=Button(wrapper2,text="CLEAR",command=clear)
    clbtn.pack(side=LEFT,padx=10)

#===============================================================
    wrapper1.pack(fill="both", expand="yes", padx=20, pady=20)
    wrapper2.pack(fill="both", expand="yes", padx=20, pady=20)
#================================================================
    def home():
        root.destroy()
        login()

    btn2=Button(wrapper2,text="HOME",width=20,bg='black',fg='white',command=home,borderwidth=6) 
    btn2.pack()


    root.mainloop()
    
    

s=StringVar()
v=StringVar()
def opemm():
    e1=v.get()
    e3=s.get()
    cursor.execute("delete from users where Vehicle_number LIKE '%"+e1+"%' and Phone_number LIKE '%"+e3+"%'")
    con.commit()
    
    
def take():
    #root1.destroy()
    root2=Tk()
    root2.geometry("900x700")
    root2.configure(bg='Teal')
    w = Frame ( root2,bg="white")
    w.place(x = 0, y = 675, width = 1800,height=10) 
    x= Frame ( root2,bg="red")
    x.place(x = 0, y = 690, width = 1800,height=10) 
    y = Frame ( root2,bg="red")
    y.place(x = 0, y = 0, width = 1800,height=10)
    z = Frame ( root2,bg="white")
    z.place(x = 0, y = 15, width = 1800,height=10)



    lb1= tk.Label(root2, text ="Fill details", fg="RED",anchor=CENTER,bd=5,bg="Teal",font='lucida') 
    lb1.place(x = 350, y = 200)


    lb3= tk.Label(root2, text ="PHONE NUMBER ", fg="white",anchor=CENTER,bd=5,bg="Teal",font="Ariel") 
    lb3.place(x = 235, y = 309)

    E1 = tk.Entry(root2, width = 35,bd=0,bg="white",textvariable=s,fg="black",font='Ariel') 
    E1.place(x = 400, y =310, width = 300) 
   
    lb2 = tk.Label(root2, text ="VECHILE ID", fg="white",anchor=CENTER,bd=5,bg="Teal",font="Ariel") 
    lb2.place(x = 255, y = 350) 
  
    E2= tk.Entry(root2, width = 35,fg="black",bg="white",textvariable=v,show="*",font='ariel') 
    E2.place(x = 400, y = 350, width = 300) 
  
    opem= tk.Button(root2, text ="OPEN",command=opemm) 
    opem.place(x = 500, y = 400, width = 200)
    
    def home():
        root2.destroy()
        login()

    btn2=Button(root2,text="HOME",width=20,bg='black',fg='white',command=home,borderwidth=6) 
    btn2.place(x=150,y=530)
    
       
#################################################################################
#                    login

def login() :
     if(pswd.get()=="123456" and user.get()=="root" ):
            
        root.destroy()
        root1=Tk()
        root1.geometry("900x700")
        root1.configure(bg='Teal')
        w = Frame ( root1,bg="white")
        w.place(x = 0, y = 675, width = 1800,height=10) 
        x= Frame ( root1,bg="red")
        x.place(x = 0, y = 690, width = 1800,height=10) 
        y = Frame ( root1,bg="red")
        y.place(x = 0, y = 0, width = 1800,height=10)
        z = Frame ( root1,bg="white")
        z.place(x = 0, y = 15, width = 1800,height=10) 
        #########################################################################
        #btn = tk.Button(root1, text ="Park Vehicle",bg ='grey',activebackground='red',bd=1,width=100) 
        #btn.place(x = 390, y = 400, width = 100) 

        btn1 = tk.Button(root1, text ="VEHICLE PARKING",bg ='grey',command=num,activebackground='cyan',bd=1,font='Ariel') 
        btn1.place(x = 25, y = 40, width = 200,height=200) 

        btn2 = tk.Button(root1, text ="TAKE VEHICLE ",bg ='grey',command=take,activebackground='white',bd=1,font='Ariel') 
        btn2.place(x = 235, y = 40, width = 200,height=200) 
          
        btn3 = tk.Button(root1, text ="CURRENT VEHICLE",bg ='grey',command=showw,activebackground='white',bd=1,font='Ariel') 
        btn3.place(x = 445, y = 40, width = 200,height=200) 
        
        btn4 = tk.Button(root1, text ="VEHICLE HISTROY ",bg ='grey',command=showw2,activebackground='white',bd=1,font='Ariel') 
        btn4.place(x = 655, y = 40, width = 200,height=200) 
  
        root1.mainloop()
     else:
       # messagebox.showerror("showerror","WRONG PASSWORD")
         pass
    
    
    
    
    
    
    lb1= tk.Label(root, text ="ADMIN LOGIN", fg="RED",anchor=CENTER,bd=5,bg="GREY",font='lucida') 
lb1.place(x = 350, y = 200)


lb1= tk.Label(root, text ="Username", fg="white",anchor=CENTER,bd=5,bg="GREY",font="Ariel") 
lb1.place(x = 370, y = 270)
Username = tk.Entry(root, width = 35,bd=0,bg="black",fg="white", textvariable=user) 
Username.place(x = 370, y =310, width = 120) 
   
lb2 = tk.Label(root, text ="Password", fg="white",anchor=CENTER,bd=5,bg="GREY",font="Ariel") 
lb2.place(x = 370, y = 330) 
      
password = tk.Entry(root, width = 35,bg="black",fg="white",show="*", textvariable=pswd) 
password.place(x = 370, y = 370, width = 120) 
  
submitbtn = tk.Button(root, text ="Login",bg ='white',command=login,bd=1) 
submitbtn.place(x = 390, y = 400, width = 55) 
root.mainloop() 


############################################################################################################################
       
###########################################################################################
